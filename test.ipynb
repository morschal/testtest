# %% [markdown]
# #Some Test

# %%
import numpy as np
a = 1
b= 2
a+b
# Out:
# 3

# %%
import numpy as np

# %%
a = 1
b = 2

# %%
a+b
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()
